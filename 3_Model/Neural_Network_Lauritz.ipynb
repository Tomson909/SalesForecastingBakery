# %% [markdown]
# # Mounting Google Drive and Loading Data

# %%
# Mounting your Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Change working directory

import os

os.chdir('/content/drive/My Drive/Colab Notebooks')

# %%
import pandas as pd

# Import your training and validation data
# Replace 'path_to_data' with the actual path of your data in Google Drive

# Corrected path to my data
data_path = '/content/drive/My Drive/Colab Notebooks'
training_features = pd.read_csv(f'{data_path}/features_train.csv')
training_labels = pd.read_csv(f'{data_path}/label_train.csv')
validation_features = pd.read_csv(f'{data_path}/features_validation.csv')
validation_labels = pd.read_csv(f'{data_path}/label_validation.csv')
test_features = pd.read_csv(f'{data_path}/features_test.csv')
test_data_IDs = pd.read_csv(f'{data_path}/test_data_IDs.csv')

# %% [markdown]
# # Defining the Neural Network
#
# Now, let's define our neural network. We are using a Sequential model definition from Keras with batch normalization and dense layers.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, BatchNormalization
from tensorflow.keras.optimizers import Adam

model = Sequential([
  InputLayer(input_shape=(training_features.shape[1], )),
  BatchNormalization(),
  Dense(10, activation='relu'),
  Dense(4, activation='relu'),
  Dense(1)
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (Batch  (None, 17)                68
#  Normalization)
#
#  dense (Dense)               (None, 10)                180
#
#  dense_1 (Dense)             (None, 4)                 44
#
#  dense_2 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 297 (1.16 KB)
# Trainable params: 263 (1.03 KB)
# Non-trainable params: 34 (136.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Compiling and Training the Model
#
# We will compile the model using Mean Squared Error (MSE) as the loss function and Adam optimizer. The model is then trained using the training data.

# %%
model.compile(loss="mse", optimizer=Adam(learning_rate=0.001))

history = model.fit(training_features, training_labels, epochs=200,
                    validation_data=(validation_features, validation_labels))
# Out:
# Epoch 1/200
# 234/234 [==============================] - 3s 5ms/step - loss: 62197.9883 - val_loss: 44357.0820
# Epoch 2/200
# 234/234 [==============================] - 1s 3ms/step - loss: 28577.1992 - val_loss: 9209.7520
# Epoch 3/200
# 234/234 [==============================] - 1s 3ms/step - loss: 10932.9043 - val_loss: 6815.3701
# Epoch 4/200
# 234/234 [==============================] - 1s 3ms/step - loss: 8548.4795 - val_loss: 5876.1025
# Epoch 5/200
# 234/234 [==============================] - 1s 3ms/step - loss: 7591.8403 - val_loss: 5562.7383
# Epoch 6/200
# 234/234 [==============================] - 1s 3ms/step - loss: 7081.8169 - val_loss: 5398.4106
# Epoch 7/200
# 234/234 [==============================] - 1s 3ms/step - loss: 6775.6504 - val_loss: 5368.8306
# Epoch 8/200
# 234/234 [==============================] - 1s 3ms/step - loss: 6853.9590 - val_loss: 5282.6689
# Epoch 9/200
# 234/234 [==============================] - 1s 3ms/step - loss: 6613.8691 - val_loss: 5171.4473
# Epoch 10/200
# 234/234 [==============================] - 1s 3ms/step - loss: 6693.5112 - val_loss: 4799.9346
# Epoch 11/200
# 234/234 [==============================] - 1s 3ms/step - loss: 6360.5132 - val_loss: 5049.0298
# Epoch 12/200
# 234/234 [==============================] - 1s 3ms/step - loss: 6297.5210 - val_loss: 4750.7026
# Epoch 13/200
# 234/234 [==============================] - 1s 3ms/step - loss: 6431.9663 - val_loss: 4629.1841
# Epoch 14/200
# 234/234 [==============================] - 1s 4ms/step - loss: 6104.5166 - val_loss: 4643.1436
# Epoch 15/200
# 234/234 [==============================] - 1s 5ms/step - loss: 6255.9966 - val_loss: 4537.2339
# Epoch 16/200
# 234/234 [==============================] - 1s 4ms/step - loss: 5932.1411 - val_loss: 4503.0654
# Epoch 17/200
# 234/234 [==============================] - 1s 5ms/step - loss: 5880.7373 - val_loss: 4569.1079
# Epoch 18/200
# 234/234 [==============================] - 1s 5ms/step - loss: 6045.0049 - val_loss: 4278.4912
# Epoch 19/200
# 234/234 [==============================] - 1s 5ms/step - loss: 5969.1509 - val_loss: 4291.8354
# Epoch 20/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5695.4453 - val_loss: 4168.1323
# Epoch 21/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5881.7178 - val_loss: 4224.1616
# Epoch 22/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5699.6577 - val_loss: 4109.8809
# Epoch 23/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5470.3726 - val_loss: 4201.5942
# Epoch 24/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5559.9697 - val_loss: 4071.9978
# Epoch 25/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5542.3154 - val_loss: 4015.4351
# Epoch 26/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5452.2544 - val_loss: 3957.3235
# Epoch 27/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5512.5581 - val_loss: 4019.8840
# Epoch 28/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5462.2437 - val_loss: 3992.2485
# Epoch 29/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5384.5581 - val_loss: 4005.0608
# Epoch 30/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5128.5552 - val_loss: 3891.4102
# Epoch 31/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5430.7729 - val_loss: 3762.3618
# Epoch 32/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5342.0181 - val_loss: 3538.8181
# Epoch 33/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5224.8389 - val_loss: 3589.7957
# Epoch 34/200
# 234/234 [==============================] - 1s 4ms/step - loss: 5346.3149 - val_loss: 3904.2373
# Epoch 35/200
# 234/234 [==============================] - 1s 5ms/step - loss: 5302.6147 - val_loss: 3676.3850
# Epoch 36/200
# 234/234 [==============================] - 1s 5ms/step - loss: 5095.1069 - val_loss: 3791.0557
# Epoch 37/200
# 234/234 [==============================] - 1s 5ms/step - loss: 5250.4214 - val_loss: 3606.8928
# Epoch 38/200
# 234/234 [==============================] - 1s 4ms/step - loss: 5134.4741 - val_loss: 3726.5044
# Epoch 39/200
# 234/234 [==============================] - 1s 4ms/step - loss: 5090.9312 - val_loss: 3814.8687
# Epoch 40/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5071.0039 - val_loss: 3743.2668
# Epoch 41/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5063.6665 - val_loss: 3734.3052
# Epoch 42/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5079.2090 - val_loss: 3727.0566
# Epoch 43/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5159.2520 - val_loss: 3743.7754
# Epoch 44/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5154.4614 - val_loss: 3847.3215
# Epoch 45/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4921.3628 - val_loss: 3589.4543
# Epoch 46/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5014.8257 - val_loss: 3531.7322
# Epoch 47/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5087.1250 - val_loss: 3740.0217
# Epoch 48/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5107.2607 - val_loss: 3805.0291
# Epoch 49/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5158.2397 - val_loss: 3501.5981
# Epoch 50/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4991.6982 - val_loss: 3481.1475
# Epoch 51/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4995.5425 - val_loss: 3502.7493
# Epoch 52/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4986.0298 - val_loss: 3428.3438
# Epoch 53/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4830.1602 - val_loss: 3507.3240
# Epoch 54/200
# 234/234 [==============================] - 1s 4ms/step - loss: 5029.9409 - val_loss: 3649.6433
# Epoch 55/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4955.1870 - val_loss: 3625.4441
# Epoch 56/200
# 234/234 [==============================] - 1s 5ms/step - loss: 5009.8857 - val_loss: 3954.4153
# Epoch 57/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4977.4966 - val_loss: 3519.4827
# Epoch 58/200
# 234/234 [==============================] - 1s 4ms/step - loss: 5084.9795 - val_loss: 3645.7581
# Epoch 59/200
# 234/234 [==============================] - 1s 5ms/step - loss: 5017.6694 - val_loss: 3407.9966
# Epoch 60/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5080.9092 - val_loss: 3795.1741
# Epoch 61/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4869.9678 - val_loss: 3586.7676
# Epoch 62/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5130.9517 - val_loss: 3316.5537
# Epoch 63/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4865.0801 - val_loss: 3484.4001
# Epoch 64/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4890.6304 - val_loss: 3544.3477
# Epoch 65/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4922.3955 - val_loss: 3579.2283
# Epoch 66/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4970.5591 - val_loss: 3761.3069
# Epoch 67/200
# 234/234 [==============================] - 1s 3ms/step - loss: 5087.6123 - val_loss: 3518.5605
# Epoch 68/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4808.5127 - val_loss: 3432.7236
# Epoch 69/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4876.9746 - val_loss: 3655.5422
# Epoch 70/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4796.2026 - val_loss: 3397.7517
# Epoch 71/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4976.8091 - val_loss: 3612.1567
# Epoch 72/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4755.2393 - val_loss: 3362.0676
# Epoch 73/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4953.0059 - val_loss: 3710.8389
# Epoch 74/200
# 234/234 [==============================] - 1s 4ms/step - loss: 4863.9316 - val_loss: 3450.4561
# Epoch 75/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4723.4800 - val_loss: 3349.9768
# Epoch 76/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4927.1196 - val_loss: 3545.2949
# Epoch 77/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4822.2402 - val_loss: 3552.3591
# Epoch 78/200
# 234/234 [==============================] - 1s 4ms/step - loss: 4876.9590 - val_loss: 3806.5381
# Epoch 79/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4996.1060 - val_loss: 3547.2346
# Epoch 80/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4878.5928 - val_loss: 3415.7910
# Epoch 81/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4857.4771 - val_loss: 3511.3555
# Epoch 82/200
# 234/234 [==============================] - 1s 4ms/step - loss: 4923.7124 - val_loss: 3377.6865
# Epoch 83/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4713.9805 - val_loss: 3410.1865
# Epoch 84/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4828.6162 - val_loss: 3357.1924
# Epoch 85/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4773.0459 - val_loss: 3694.9836
# Epoch 86/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4742.9634 - val_loss: 3342.8530
# Epoch 87/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4943.2861 - val_loss: 3789.2922
# Epoch 88/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4634.4082 - val_loss: 3359.7209
# Epoch 89/200
# 234/234 [==============================] - 1s 4ms/step - loss: 4860.8032 - val_loss: 4034.0610
# Epoch 90/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4759.7217 - val_loss: 3562.4700
# Epoch 91/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4667.5239 - val_loss: 3416.0938
# Epoch 92/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4736.4038 - val_loss: 3305.5005
# Epoch 93/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4646.2832 - val_loss: 3535.5571
# Epoch 94/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4947.5933 - val_loss: 3364.2324
# Epoch 95/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4839.9468 - val_loss: 3410.3481
# Epoch 96/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4765.7471 - val_loss: 3570.9531
# Epoch 97/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4709.9907 - val_loss: 3413.9985
# Epoch 98/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4811.7603 - val_loss: 3284.6038
# Epoch 99/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4867.3159 - val_loss: 3445.4199
# Epoch 100/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4845.6758 - val_loss: 3539.9966
# Epoch 101/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4753.9277 - val_loss: 3675.3208
# Epoch 102/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4862.3018 - val_loss: 3725.6279
# Epoch 103/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4820.8569 - val_loss: 3512.6987
# Epoch 104/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4721.7100 - val_loss: 3563.0596
# Epoch 105/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4652.5215 - val_loss: 3576.3962
# Epoch 106/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4848.1626 - val_loss: 3459.3762
# Epoch 107/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4811.9941 - val_loss: 3887.4624
# Epoch 108/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4879.2700 - val_loss: 4013.8716
# Epoch 109/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4676.5913 - val_loss: 3341.3979
# Epoch 110/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4799.5078 - val_loss: 3453.5381
# Epoch 111/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4833.3623 - val_loss: 3543.9011
# Epoch 112/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4837.6045 - val_loss: 3445.8342
# Epoch 113/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4797.4648 - val_loss: 3320.6436
# Epoch 114/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4837.9189 - val_loss: 3706.9016
# Epoch 115/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4749.5708 - val_loss: 3301.0928
# Epoch 116/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4673.2134 - val_loss: 3264.6335
# Epoch 117/200
# 234/234 [==============================] - 1s 4ms/step - loss: 4639.6401 - val_loss: 3472.9443
# Epoch 118/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4650.4033 - val_loss: 3620.4583
# Epoch 119/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4726.3418 - val_loss: 3401.8374
# Epoch 120/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4677.1748 - val_loss: 3547.1533
# Epoch 121/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4817.6338 - val_loss: 3561.5547
# Epoch 122/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4840.4458 - val_loss: 3325.3643
# Epoch 123/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4744.3071 - val_loss: 3362.3591
# Epoch 124/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4707.3184 - val_loss: 3515.2793
# Epoch 125/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4733.5825 - val_loss: 3761.1638
# Epoch 126/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4807.5708 - val_loss: 3607.9639
# Epoch 127/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4692.8613 - val_loss: 3558.9739
# Epoch 128/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4764.7339 - val_loss: 3454.5549
# Epoch 129/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4788.2949 - val_loss: 3681.3542
# Epoch 130/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4796.4961 - val_loss: 3279.2495
# Epoch 131/200
# 234/234 [==============================] - 1s 4ms/step - loss: 4668.0674 - val_loss: 3579.5295
# Epoch 132/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4700.8774 - val_loss: 3460.7249
# Epoch 133/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4700.4136 - val_loss: 3736.9478
# Epoch 134/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4694.2334 - val_loss: 3333.6558
# Epoch 135/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4670.1680 - val_loss: 3561.7766
# Epoch 136/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4608.1870 - val_loss: 3459.2415
# Epoch 137/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4815.9619 - val_loss: 3785.0669
# Epoch 138/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4627.5410 - val_loss: 3543.1084
# Epoch 139/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4697.6250 - val_loss: 3427.3914
# Epoch 140/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4778.6528 - val_loss: 3369.2068
# Epoch 141/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4671.7988 - val_loss: 3856.1841
# Epoch 142/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4737.8906 - val_loss: 3687.1975
# Epoch 143/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4659.7144 - val_loss: 3331.3596
# Epoch 144/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4684.4360 - val_loss: 3471.3582
# Epoch 145/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4548.4067 - val_loss: 3584.3889
# Epoch 146/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4552.5220 - val_loss: 3628.7048
# Epoch 147/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4610.4385 - val_loss: 3523.6016
# Epoch 148/200
# 234/234 [==============================] - 1s 4ms/step - loss: 4703.1533 - val_loss: 3454.2219
# Epoch 149/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4655.2939 - val_loss: 3333.0557
# Epoch 150/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4578.8892 - val_loss: 3480.2368
# Epoch 151/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4698.4917 - val_loss: 3383.2395
# Epoch 152/200
# 234/234 [==============================] - 1s 4ms/step - loss: 4525.2119 - val_loss: 3517.3965
# Epoch 153/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4685.3989 - val_loss: 3641.7678
# Epoch 154/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4534.9668 - val_loss: 3777.6938
# Epoch 155/200
# 234/234 [==============================] - 1s 4ms/step - loss: 4595.6523 - val_loss: 3650.6406
# Epoch 156/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4593.3013 - val_loss: 3546.1221
# Epoch 157/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4636.6909 - val_loss: 3508.7903
# Epoch 158/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4701.7754 - val_loss: 3547.5757
# Epoch 159/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4582.5532 - val_loss: 3365.7522
# Epoch 160/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4732.4438 - val_loss: 3585.0825
# Epoch 161/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4634.5200 - val_loss: 3604.1570
# Epoch 162/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4648.5171 - val_loss: 3805.6677
# Epoch 163/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4695.8164 - val_loss: 3426.3140
# Epoch 164/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4591.8457 - val_loss: 3532.0945
# Epoch 165/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4585.0254 - val_loss: 3712.2471
# Epoch 166/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4591.0688 - val_loss: 3700.7107
# Epoch 167/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4593.9390 - val_loss: 3589.1746
# Epoch 168/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4664.4136 - val_loss: 3400.9385
# Epoch 169/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4715.8979 - val_loss: 3837.5403
# Epoch 170/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4653.3818 - val_loss: 3353.4561
# Epoch 171/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4439.8789 - val_loss: 3435.2085
# Epoch 172/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4585.1411 - val_loss: 3649.0720
# Epoch 173/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4672.4829 - val_loss: 3547.6501
# Epoch 174/200
# 234/234 [==============================] - 1s 4ms/step - loss: 4610.5635 - val_loss: 3693.9153
# Epoch 175/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4541.6885 - val_loss: 3475.4314
# Epoch 176/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4487.7837 - val_loss: 3458.8167
# Epoch 177/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4650.2759 - val_loss: 3524.2864
# Epoch 178/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4645.4116 - val_loss: 3362.3870
# Epoch 179/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4593.3203 - val_loss: 3490.7837
# Epoch 180/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4626.5801 - val_loss: 3720.0422
# Epoch 181/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4572.8574 - val_loss: 3428.1746
# Epoch 182/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4574.9258 - val_loss: 3640.9307
# Epoch 183/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4591.6089 - val_loss: 3409.3259
# Epoch 184/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4542.2412 - val_loss: 3615.6814
# Epoch 185/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4656.1304 - val_loss: 3642.5410
# Epoch 186/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4620.9644 - val_loss: 3289.7344
# Epoch 187/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4599.8071 - val_loss: 3636.9736
# Epoch 188/200
# 234/234 [==============================] - 1s 4ms/step - loss: 4622.1006 - val_loss: 3795.7751
# Epoch 189/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4395.8140 - val_loss: 3633.1096
# Epoch 190/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4559.1479 - val_loss: 3670.0425
# Epoch 191/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4710.4814 - val_loss: 3408.1951
# Epoch 192/200
# 234/234 [==============================] - 1s 4ms/step - loss: 4656.3555 - val_loss: 3739.7073
# Epoch 193/200
# 234/234 [==============================] - 1s 5ms/step - loss: 4598.4565 - val_loss: 3495.0486
# Epoch 194/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4602.2373 - val_loss: 3520.0293
# Epoch 195/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4653.0996 - val_loss: 3443.6626
# Epoch 196/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4712.7061 - val_loss: 3631.6030
# Epoch 197/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4471.0513 - val_loss: 3346.3401
# Epoch 198/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4484.4199 - val_loss: 3569.1077
# Epoch 199/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4595.3501 - val_loss: 3700.8477
# Epoch 200/200
# 234/234 [==============================] - 1s 3ms/step - loss: 4606.0269 - val_loss: 3577.1252

# %% [markdown]
# # Saving the Trained Model
#
# After training, it's a good practice to save the model for future use.

# %% [markdown]
# # Plotting Training History
#
# Visualizing the training and validation loss can help us understand the model's performance over time.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss During Training')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Making Predictions and Evaluating the Model
#
# Let's use the model to make predictions on our training and validation sets and evaluate the model's performance using Mean Absolute Percentage Error (MAPE).

# %%
import numpy as np

def mape(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    non_zero_mask = y_true != 0
    return np.mean(np.abs((y_true[non_zero_mask] - y_pred[non_zero_mask]) / y_true[non_zero_mask])) * 100

training_predictions = model.predict(training_features)
validation_predictions = model.predict(validation_features)
training_predictions
print(f"MAPE on the Training Data: {mape(training_labels, training_predictions):.2f}%")
print(f"MAPE on the Validation Data: {mape(validation_labels, validation_predictions):.2f}%")
# Out:
# 234/234 [==============================] - 1s 2ms/step
# 56/56 [==============================] - 0s 3ms/step
# MAPE on the Training Data: 23.12%
# MAPE on the Validation Data: 24.99%

# %% [markdown]
# # Visualizing Predictions vs Actual Values
#
# Visualizing the predicted versus actual values can provide insights into the model's accuracy

# %% [markdown]
# # Example of a Prediction and Export of Test Data for Kaggle
#
# Finally, for testing data on Kaggle you have to do a prediction for the test data and format it in the format needed by Kaggle.
#
# The code below provides an example that you can use

# %%
# Extract IDs and prepare test features
test_ids = test_data_IDs['id']

# Make predictions
test_predictions = model.predict(test_features)

# Create a DataFrame for submission
predictions_df = pd.DataFrame({
    'id': test_ids,
    'Umsatz': test_predictions.flatten()  # Replace column name with the one given in sample_submission.csv
})

# Export to CSV
predictions_df.to_csv('kaggle_submission.csv', index=False)
# Out:
# 56/56 [==============================] - 0s 2ms/step
